# %% [markdown]
# # 0. Install and import the libraries

# %%
#%pip install numpy
#%pip install tensorflow
#%pip install keras
#%pip install matplotlib

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras import layers
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Set Random Seed for Reproducibility

# %%
np.random.seed(42)
tf.random.set_seed(42)
batch_size = 64

# %% [markdown]
# # 2. Load and Preprocess the MNIST Dataset

# %%
# Load the MNIST dataset
(x_train, y_train_orig), (x_test, y_test_orig) = keras.datasets.mnist.load_data()

# Normalize the images to [0, 1] range and flatten them
x_train = x_train.astype('float32') / 255.0
x_train_flat = x_train.reshape(-1, 28 * 28)
x_test = x_test.astype('float32') / 255.0
x_test_flat = x_test.reshape(-1, 28 * 28)

# Convert labels to one-hot encoded vectors
num_classes = 10
y_train = keras.utils.to_categorical(y_train_orig, num_classes)
y_test = keras.utils.to_categorical(y_test_orig, num_classes)

# %% [markdown]
# # 3. Hyperparameters

# %%
''' TODO: Adjust the following parameters with different values. Save the plots and test results for each setup.
    TODO: write a report about your findings from varying the parameters and their effect on overall performance. '''

# lr: 0.1, 0.01, ...
# epoch: 5, 10, 50, ...
# layer: [128], [256, 256], ... .
learning_rate = 0.01
num_epochs = 50
hidden_layers = [800]

# %% [markdown]
# # 4. Define the Neural Network Model

# %%
def create_mlp_model(input_size, hidden_layers, output_size):
    model = keras.Sequential()

    # Input layer is defined by specifying input_shape in the first layer
    for i, units in enumerate(hidden_layers):
        if i == 0:
            # First hidden layer with input shape specified
            model.add(layers.Dense(units, activation='relu', input_shape=(input_size,)))
        else:
            # Subsequent hidden layers
            model.add(layers.Dense(units, activation='relu'))

    # Output layer with softmax activation for multi-class classification
    model.add(layers.Dense(output_size, activation='softmax'))

    return model

# Model parameters
input_size = 28 * 28  # MNIST images are 28x28 pixels
output_size = num_classes  # 10 classes for digits 0-9

# Create the model
model = create_mlp_model(input_size, hidden_layers, output_size)

# %% [markdown]
# # 5. Compile the Model

# %%
model.compile(
    optimizer=keras.optimizers.SGD(learning_rate=learning_rate),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# # 6. Train the Model

# %%
history = model.fit(
    x_train_flat, y_train,
    epochs=num_epochs,
    batch_size=batch_size,
    validation_split=0.1,  # Use 10% of training data for validation
    verbose=1
)
# Out:
# Epoch 1/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8137 - loss: 0.8314 - val_accuracy: 0.9068 - val_loss: 0.3955
# Epoch 2/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8919 - loss: 0.4113 - val_accuracy: 0.9202 - val_loss: 0.3033
# Epoch 3/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9050 - loss: 0.3466 - val_accuracy: 0.9278 - val_loss: 0.2676
# Epoch 4/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9131 - loss: 0.3129 - val_accuracy: 0.9322 - val_loss: 0.2458
# Epoch 5/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9200 - loss: 0.2898 - val_accuracy: 0.9352 - val_loss: 0.2297
# Epoch 6/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9252 - loss: 0.2717 - val_accuracy: 0.9400 - val_loss: 0.2167
# Epoch 7/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9293 - loss: 0.2567 - val_accuracy: 0.9438 - val_loss: 0.2056
# Epoch 8/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9331 - loss: 0.2437 - val_accuracy: 0.9475 - val_loss: 0.1959
# Epoch 9/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9364 - loss: 0.2323 - val_accuracy: 0.9508 - val_loss: 0.1873
# Epoch 10/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9390 - loss: 0.2219 - val_accuracy: 0.9533 - val_loss: 0.1797
# Epoch 11/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9414 - loss: 0.2126 - val_accuracy: 0.9552 - val_loss: 0.1728
# Epoch 12/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9437 - loss: 0.2040 - val_accuracy: 0.9568 - val_loss: 0.1665
# Epoch 13/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9459 - loss: 0.1960 - val_accuracy: 0.9585 - val_loss: 0.1607
# Epoch 14/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9478 - loss: 0.1887 - val_accuracy: 0.9602 - val_loss: 0.1554
# Epoch 15/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9494 - loss: 0.1819 - val_accuracy: 0.9615 - val_loss: 0.1506
# Epoch 16/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9510 - loss: 0.1755 - val_accuracy: 0.9618 - val_loss: 0.1461
# Epoch 17/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9527 - loss: 0.1695 - val_accuracy: 0.9628 - val_loss: 0.1419
# Epoch 18/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9542 - loss: 0.1639 - val_accuracy: 0.9635 - val_loss: 0.1380
# Epoch 19/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9556 - loss: 0.1586 - val_accuracy: 0.9645 - val_loss: 0.1344
# Epoch 20/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9573 - loss: 0.1537 - val_accuracy: 0.9655 - val_loss: 0.1311
# Epoch 21/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9587 - loss: 0.1490 - val_accuracy: 0.9660 - val_loss: 0.1279
# Epoch 22/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9603 - loss: 0.1446 - val_accuracy: 0.9670 - val_loss: 0.1250
# Epoch 23/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9612 - loss: 0.1404 - val_accuracy: 0.9675 - val_loss: 0.1222
# Epoch 24/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9626 - loss: 0.1365 - val_accuracy: 0.9692 - val_loss: 0.1196
# Epoch 25/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9637 - loss: 0.1327 - val_accuracy: 0.9697 - val_loss: 0.1172
# Epoch 26/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9647 - loss: 0.1291 - val_accuracy: 0.9695 - val_loss: 0.1150
# Epoch 27/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9656 - loss: 0.1258 - val_accuracy: 0.9707 - val_loss: 0.1129
# Epoch 28/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9665 - loss: 0.1225 - val_accuracy: 0.9710 - val_loss: 0.1109
# Epoch 29/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9672 - loss: 0.1195 - val_accuracy: 0.9715 - val_loss: 0.1090
# Epoch 30/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9680 - loss: 0.1165 - val_accuracy: 0.9720 - val_loss: 0.1072
# Epoch 31/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9687 - loss: 0.1137 - val_accuracy: 0.9725 - val_loss: 0.1055
# Epoch 32/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9696 - loss: 0.1110 - val_accuracy: 0.9725 - val_loss: 0.1039
# Epoch 33/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9704 - loss: 0.1085 - val_accuracy: 0.9730 - val_loss: 0.1024
# Epoch 34/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9711 - loss: 0.1060 - val_accuracy: 0.9735 - val_loss: 0.1009
# Epoch 35/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9719 - loss: 0.1036 - val_accuracy: 0.9737 - val_loss: 0.0995
# Epoch 36/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9726 - loss: 0.1014 - val_accuracy: 0.9740 - val_loss: 0.0982
# Epoch 37/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9734 - loss: 0.0992 - val_accuracy: 0.9743 - val_loss: 0.0969
# Epoch 38/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9739 - loss: 0.0971 - val_accuracy: 0.9743 - val_loss: 0.0958
# Epoch 39/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9746 - loss: 0.0951 - val_accuracy: 0.9748 - val_loss: 0.0946
# Epoch 40/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9751 - loss: 0.0931 - val_accuracy: 0.9755 - val_loss: 0.0935
# Epoch 41/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9756 - loss: 0.0913 - val_accuracy: 0.9758 - val_loss: 0.0925
# Epoch 42/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9764 - loss: 0.0895 - val_accuracy: 0.9762 - val_loss: 0.0915
# Epoch 43/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9768 - loss: 0.0877 - val_accuracy: 0.9768 - val_loss: 0.0905
# Epoch 44/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9773 - loss: 0.0860 - val_accuracy: 0.9768 - val_loss: 0.0896
# Epoch 45/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9777 - loss: 0.0844 - val_accuracy: 0.9772 - val_loss: 0.0887
# Epoch 46/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9782 - loss: 0.0828 - val_accuracy: 0.9775 - val_loss: 0.0878
# Epoch 47/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9786 - loss: 0.0813 - val_accuracy: 0.9782 - val_loss: 0.0870
# Epoch 48/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9791 - loss: 0.0798 - val_accuracy: 0.9782 - val_loss: 0.0862
# Epoch 49/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9795 - loss: 0.0783 - val_accuracy: 0.9783 - val_loss: 0.0854
# Epoch 50/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9800 - loss: 0.0769 - val_accuracy: 0.9783 - val_loss: 0.0847

# %% [markdown]
# # 7. Evaluate the Model on Test Data

# %%
test_loss, test_accuracy = model.evaluate(x_test_flat, y_test, verbose=0)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')
# Out:
# Test Accuracy: 97.21%

# %% [markdown]
# # 8. Visualize Training History

# %%
plt.figure(figsize=(12, 5))

# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %% [markdown]
# # 9. Test the Model on Random Input Data

# %%
# Select random samples from the test set
num_samples = 5
random_indices = np.random.choice(x_test.shape[0], num_samples, replace=False)
random_images = x_test[random_indices]
random_images_flat = x_test_flat[random_indices]
random_labels = y_test_orig[random_indices]

# Predict the labels of the random images
predictions = model.predict(random_images_flat)
predicted_labels = np.argmax(predictions, axis=1)

# Plot the random images along with predicted and true labels
plt.figure(figsize=(15, 3))
for i in range(num_samples):
    plt.subplot(1, num_samples, i+1)
    plt.imshow(random_images[i], cmap='gray')
    plt.title(f"True: {random_labels[i]}\nPredicted: {predicted_labels[i]}")
    plt.axis('off')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
